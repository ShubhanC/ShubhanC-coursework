# %% [markdown]
# # Shrink Images for Project Mosaic
#
# If you use have many large images, this notebook contains the code to shrink your images to allow the mosaic to run quicker!
#
# - Run both of the below cells to shrink all your images.
# - Make sure your file folder is correct in the variables below:

# %%
# What folder contains your tile images?
tileImageFolder = "insta-tiles"

# What is the size of your final, smaller tile images?
# - Your image will be resized to `tileImageDimension` x `tileImageDimension`
tileImageDimension = 32

# What is the new folder for your smaller tile images?
smallTileImageFolder = f"{tileImageFolder}-small"

# %%
import DISCOVERY
from PIL import Image
import os

os.makedirs(smallTileImageFolder, exist_ok=True)

for fileName in os.listdir(tileImageFolder):
  fullPath = os.path.join(tileImageFolder, fileName)
  if os.path.isfile(fullPath) and DISCOVERY.isImageFile(fullPath):
    print(f"Shrinking {fullPath}...")
    image = Image.open(fullPath)
    width, height = image.size
    dimension = min(width, height)
    image = image.crop((0, 0, dimension, dimension))
    image = image.resize((tileImageDimension, tileImageDimension), resample=Image.Resampling.LANCZOS)
    image.save(os.path.join(smallTileImageFolder, fileName))

tada = "\N{PARTY POPPER}"
print()
print(f"{tada} SHRINK COMPLETE!")
print(f"- All image files in \"{tileImageFolder}\" are now {tileImageDimension}px x {tileImageDimension}px and saved in \"{smallTileImageFolder}\".")
print(f"- Use \"{smallTileImageFolder}\" as your tile image folder to run the mosaic creation much faster!")
# Out:
# Shrinking insta-tiles/IMG_4064.PNG...
# Shrinking insta-tiles/IMG_4058.PNG...
# Shrinking insta-tiles/IMG_2830.JPG...
# Shrinking insta-tiles/278737097_1066977160829905_8440751541906555304_n_17846970521759395.jpg...
# Shrinking insta-tiles/Screenshot 2024-10-14 at 4.13.26 PM.png...
# Shrinking insta-tiles/316001465_673102974368405_2835525531455069911_n_17971632763804398.jpg...
# Shrinking insta-tiles/Screenshot 2024-10-14 at 4.13.49 PM.png...
# Shrinking insta-tiles/IMG_3657.JPG...
# Shrinking insta-tiles/Screenshot 2024-10-14 at 2.56.20 PM.png...
# Shrinking insta-tiles/IMG_2993.JPG...
# Shrinking insta-tiles/IMG_3455.JPG...
# Shrinking insta-tiles/IMG_2992.JPG...
# Shrinking insta-tiles/Screenshot 2024-10-14 at 4.04.21 PM.png...
# Shrinking insta-tiles/Screenshot 2024-10-14 at 2.56.08 PM.png...
# Shrinking insta-tiles/318952631_1651801298586025_7656134716603319606_n_17964065278965182.jpg...
# Shrinking insta-tiles/IMG_4059.PNG...
# Shrinking insta-tiles/IMG_4065.PNG...
# Shrinking insta-tiles/IMG_4067.PNG...
# Shrinking insta-tiles/IMG_3720.JPG...
# Shrinking insta-tiles/image000004.jpg...
# Shrinking insta-tiles/IMG_3324.JPG...
# Shrinking insta-tiles/IMG_3443.JPG...
# Shrinking insta-tiles/Screenshot 2024-10-14 at 2.43.57 PM.png...
# Shrinking insta-tiles/Screenshot 2024-10-14 at 3.28.09 PM.png...
# Shrinking insta-tiles/IMG_3090.JPG...
# Shrinking insta-tiles/IMG_3251.JPG...
# Shrinking insta-tiles/IMG_4066.PNG...
# Shrinking insta-tiles/IMG_4062.PNG...
# Shrinking insta-tiles/IMG_2639.JPG...
# Shrinking insta-tiles/IMG_3057.JPG...
# Shrinking insta-tiles/IMG_3719.JPG...
# Shrinking insta-tiles/IMG_3692.JPG...
# Shrinking insta-tiles/Screenshot 2024-10-14 at 2.00.06 PM.png...
# Shrinking insta-tiles/IMG_3123.JPG...
# Shrinking insta-tiles/IMG_3645.JPG...
# Shrinking insta-tiles/453868839_843288527775657_6164323899848989891_n_18002122349424873.jpg...
# Shrinking insta-tiles/IMG_3321.JPG...
# Shrinking insta-tiles/IMG_3309.JPG...
# Shrinking insta-tiles/IMG_3334.JPG...
# Shrinking insta-tiles/IMG_2572.JPG...
# Shrinking insta-tiles/IMG_3693.JPG...
# Shrinking insta-tiles/IMG_3730.JPG...
# Shrinking insta-tiles/IMG_2604.JPG...
# Shrinking insta-tiles/IMG_3254.JPG...
# Shrinking insta-tiles/IMG_4063.PNG...
# Shrinking insta-tiles/Screenshot 2024-10-14 at 4